# %%
print('hello world')
# Out:
# hello world

# %%
# !ls
# Out:
# "ls" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
# !pwd
# Out:
# "pwd" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
$pwd
# Out:
#   Cell In[6], line 1
#     $pwd
#     ^
# SyntaxError: invalid syntax

# %%
print("!ls")
# Out:
# !ls

# %%
var_ls = !ls -l

# %%
type(var_ls)
# Out:
# IPython.utils.text.SList

# %%
ls = !ls -l /usr/bin

# %%
ls.grep('.')
# Out:
# ['"ls" \xadҐ пў«пҐвбп ў\xadгваҐ\xad\xadҐ© Ё«Ё ў\xadҐи\xadҐ©',
#  'Є®¬\xa0\xad¤®©, ЁбЇ®«\xadпҐ¬®© Їа®Ја\xa0¬¬®© Ё«Ё Ї\xa0ЄҐв\xadл¬ д\xa0©«®¬.']

# %%
with open('requirments.txt', 'r') as open_file:
    lines = open_file.readlines()
    print(lines)
# Out:
# ['яюC\x00o\x00l\x00l\x00e\x00c\x00t\x00i\x00n\x00g\x00 \x00i\x00p\x00y\x00t\x00h\x00o\x00n\x00\n', '\x00\n', '\x00 \x00 \x00O\x00b\x00t\x00a\x00i\x00n\x00i\x00n\x00g\x00 \x001\x002\x003\x00d\x00e\x00p\x00e\x00n\x00d\x00e\x00n\x00c\x00y\x00 \x00i\x00n\x00f\x00o\x00r\x00m\x00a\x00t\x00i\x00o\x00n\x00 \x00f\x00o\x00r\x00 \x00i\x00p\x00y\x00t\x00h\x00o\x00n\x00 \x00f\x00r\x00o\x00m\x00 \x00h\x00t\x00t\x00p\x00s\x00:\x00/\x00/\x00f\x00i\x00l\x00e\x00s\x00.\x00p\x00y\x00t\x00h\x00o\x00n\x00h\x00o\x00s\x00t\x00e\x00d\x00.\x00o\x00r\x00g\x00/\x00p\x00a\x00c\x00k\x00a\x00g\x00e\x00s\x00/\x004\x007\x00/\x006\x00b\x00/\x00d\x009\x00f\x00d\x00c\x00d\x00e\x00f\x002\x00e\x00b\x006\x00a\x002\x003\x00f\x003\x009\x001\x002\x005\x001\x00f\x00d\x00e\x008\x007\x008\x001\x00c\x003\x008\x00d\x004\x002\x00a\x00c\x00d\x008\x002\x00a\x00b\x00e\x008\x004\x00d\x000\x005\x004\x00c\x00b\x007\x004\x00f\x007\x008\x006\x003\x00b\x000\x00/\x00i\x00p\x00y\x00t\x00h\x00o\x00n\x00-\x008\x00.\x001\x008\x00.\x001\x00-\x0
# ...

# %%
lines[1]
# Out:
# '\x00\n'

# %%
lines[2]
# Out:
# '\x00 \x00 \x00O\x00b\x00t\x00a\x00i\x00n\x00i\x00n\x00g\x00 \x00d\x00e\x00p\x00e\x00n\x00d\x00e\x00n\x00c\x00y\x00 \x00i\x00n\x00f\x00o\x00r\x00m\x00a\x00t\x00i\x00o\x00n\x00 \x00f\x00o\x00r\x00 \x00i\x00p\x00y\x00t\x00h\x00o\x00n\x00 \x00f\x00r\x00o\x00m\x00 \x00h\x00t\x00t\x00p\x00s\x00:\x00/\x00/\x00f\x00i\x00l\x00e\x00s\x00.\x00p\x00y\x00t\x00h\x00o\x00n\x00h\x00o\x00s\x00t\x00e\x00d\x00.\x00o\x00r\x00g\x00/\x00p\x00a\x00c\x00k\x00a\x00g\x00e\x00s\x00/\x004\x007\x00/\x006\x00b\x00/\x00d\x009\x00f\x00d\x00c\x00d\x00e\x00f\x002\x00e\x00b\x006\x00a\x002\x003\x00f\x003\x009\x001\x002\x005\x001\x00f\x00d\x00e\x008\x007\x008\x001\x00c\x003\x008\x00d\x004\x002\x00a\x00c\x00d\x008\x002\x00a\x00b\x00e\x008\x004\x00d\x000\x005\x004\x00c\x00b\x007\x004\x00f\x007\x008\x006\x003\x00b\x000\x00/\x00i\x00p\x00y\x00t\x00h\x00o\x00n\x00-\x008\x00.\x001\x008\x00.\x001\x00-\x00p\x00y\x003\x00-\x00n\x00o\x00n\x00e\x00-\x00a\x00n\x00y\x00.\x00w\x00h\x00l\x00.\x00m\x00e\x00t\x00a\x00d\x00a\x00t\x00a\x
# ...

# %%
lines[3]
# Out:
# '\x00\n'

# %%
import pathlib

# %%
path = pathlib.Path('C:\Users\Zatoichi\Downloads')
# Out:
#   Cell In[21], line 1
#     path = pathlib.Path('C:\Users\Zatoichi\Downloads')
#                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
path = pathlib.Path("C:\Users\Zatoichi\Downloads\sample2.txt")
# Out:
#   Cell In[23], line 1
#     path = pathlib.Path("C:\Users\Zatoichi\Downloads\sample2.txt")
#                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
with open('data.JSON', 'r') as op:
    lines = op.readlines()
    print(lines)
# Out:
# ['[\n', '  {\n', '    "name": "Augustus Larkin III",\n', '    "phoneNumber": "210-204-7681",\n', '    "email": "mason33@donnelly.com",\n', '    "address": "942 Vandervort Common\\nMargaritaland, NE 50702",\n', '    "userAgent": "Mozilla/5.0 (Macintosh; PPC Mac OS X 10_7_7 rv:3.0; sl-SI) AppleWebKit/534.48.5 (KHTML, like Gecko) Version/5.0.2 Safari/534.48.5",\n', '    "hexcolor": "#06a58f"\n', '  },\n', '  {\n', '    "name": "Cynthia Moore",\n', '    "phoneNumber": "+1-671-767-8871",\n', '    "email": "markus59@hotmail.com",\n', '    "address": "8284 Zieme Hollow\\nPort Rylanchester, NM 19308-5943",\n', '    "userAgent": "Mozilla/5.0 (X11; Linux i686; rv:6.0) Gecko/20150104 Firefox/36.0",\n', '    "hexcolor": "#10dbf9"\n', '  },\n', '  {\n', '    "name": "Dr. Weldon Jones III",\n', '    "phoneNumber": "+1-258-233-9637",\n', '    "email": "katrina.grady@corwin.com",\n', '    "address": "938 Kerluke Pike Apt. 060\\nLakinfort, WV 22990-7995",\n', '    "userAgent": "Opera/9.87 (X11; Linux
# ...

# %%
# !ls -l
# Out:
# "ls" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
import json

# %%
with open('data.JSON', 'r') as op:
    json_file = json.load(op)

# %%
from pprint import pprint

# %%
pprint(json_file)
# Out:
# [{'address': '942 Vandervort Common\nMargaritaland, NE 50702',
#   'email': 'mason33@donnelly.com',
#   'hexcolor': '#06a58f',
#   'name': 'Augustus Larkin III',
#   'phoneNumber': '210-204-7681',
#   'userAgent': 'Mozilla/5.0 (Macintosh; PPC Mac OS X 10_7_7 rv:3.0; sl-SI) '
#                'AppleWebKit/534.48.5 (KHTML, like Gecko) Version/5.0.2 '
#                'Safari/534.48.5'},
#  {'address': '8284 Zieme Hollow\nPort Rylanchester, NM 19308-5943',
#   'email': 'markus59@hotmail.com',
#   'hexcolor': '#10dbf9',
#   'name': 'Cynthia Moore',
#   'phoneNumber': '+1-671-767-8871',
#   'userAgent': 'Mozilla/5.0 (X11; Linux i686; rv:6.0) Gecko/20150104 '
#                'Firefox/36.0'},
#  {'address': '938 Kerluke Pike Apt. 060\nLakinfort, WV 22990-7995',
#   'email': 'katrina.grady@corwin.com',
#   'hexcolor': '#311e63',
#   'name': 'Dr. Weldon Jones III',
#   'phoneNumber': '+1-258-233-9637',
#   'userAgent': 'Opera/9.87 (X11; Linux x86_64; sl-SI) Presto/2.10.263 '
# ...

# %%
line = '127.0.0.1 - rj [13/Nov/2019:14:43:30 -0000] "GET HTTP/1.0" 200'

# %%
import re

# %%
print(re.search(r'\d+\.\d+\.\d+\.\d+', line))
# Out:
# <re.Match object; span=(0, 9), match='127.0.0.1'>

# %%
re.search(r'?P<IP>\d+\.\d+\.\d+\.\d+', line)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 re.search(r'?P<IP>\d+\.\d+\.\d+\.\d+', line)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\re.py:201, in search(pattern, string, flags)
#     198 def search(pattern, string, flags=0):
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\re.py:304, in _compile(pattern, flags)
#     302 if not sre_compile.isstring(pattern):
#     303     raise TypeError("first argument must be string or compiled pattern")
# --> 304 p = sre_compile.compile(pattern, flags)
#     305 if not (flags & DEBUG):
#     306     if len(_cache) >= _MAXCACHE:
#     307         # Drop the oldest item
#
# ...

# %% [raw]
# m = re.search(r'(?P<IP>\d+\.\d+\.\d+\.\d+)', line)
# m.group('IP')

# %%
line
# Out:
# '127.0.0.1 - rj [13/Nov/2019:14:43:30 -0000] "GET HTTP/1.0" 200'

# %%
r = r'(?P<Time>\d+/[A-z][a-z]{2}/\d+:\d+:\d+:\d+)'
re.search(r, line)
# Out:
# <re.Match object; span=(16, 36), match='13/Nov/2019:14:43:30'>

# %%
a = '123'
a.encode()
# Out:
# b'123'

# %%
import hashlib
md5 = hashlib.sha256()
md5.update(a.encode())

# %%
md5.digest()
# Out:
# b'\xa6e\xa4Y B/\x9dA~Hg\xef\xdcO\xb8\xa0J\x1f?\xff\x1f\xa0~\x99\x8e\x86\xf7\xf7\xa2z\xe3'

# %% [markdown]
# print(md5)

# %%
md5
# Out:
# <sha256 _hashlib.HASH object @ 0x000001FF5046C2B0>

# %%
import os

# %%
os.environ
# Out:
# environ{'PSEXECUTIONPOLICYPREFERENCE': 'RemoteSigned',
#         'TERM_SESSION_ID': 'bbfcbf77-e5f7-49fb-8dad-1c09691943bd',
#         'VIRTUAL_ENV': 'E:\\ipy',
#         'VIRTUAL_ENV_PROMPT': 'ipy',
#         'ZES_ENABLE_SYSMAN': '1',
#         'PROGRAMW6432': 'C:\\Program Files',
#         'PYCHARM': 'C:\\Program Files\\JetBrains\\PyCharm 2023.2.5\\bin;',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'FIG_JETBRAINS_SHELL_INTEGRATION': '1',
#         'USERNAME': 'Zatoichi',
#         'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'USERPROFILE': 'C:\\Users\\Zatoichi',
#         'PROCESSOR_REVISION': '9e0a',
#         'IDEA_INITIAL_DIRECTORY': 'C:\\Program Files\\JetBrains\\PyCharm Community Edition 2023.2.5\\bin',
#         'COMPOSE_CONVERT_WINDOWS_PATHS': 'true',
#         'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#         'PUBLIC': 'C:\\Users\\Public',
# ...

# %%
os.getlogin()
# Out:
# 'Zatoichi'

# %%
import subprocess

# %%
cp = subprocess.run(['ll'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 cp = subprocess.run(['ll'])
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     502     kwargs['stdout'] = PIPE
#     503     kwargs['stderr'] = PIPE
# --> 505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
#     507         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
# ...

# %%
clear()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 clear()
#
# NameError: name 'clear' is not defined

# %%
import fire

# %%
import fire

# %%
import molotov

# %%
@molotov.scenario(100)
async def scenario_get(session):
    async with session.get("http://127.0.0.1:8000/api") as resp:
        assert resp.status == 200
